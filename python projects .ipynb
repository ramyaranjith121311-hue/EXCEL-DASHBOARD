# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install python
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement python (from versions: none)
# ERROR: No matching distribution found for python

# %%
install pandas
# Out:
#   Cell In[4], line 1
#     install pandas
#             ^
# SyntaxError: invalid syntax

# %%
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import numpy as np
#
# ModuleNotFoundError: No module named 'numpy'

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 965.9 kB/s eta 0:00:11
#    -- ------------------------------------- 0.8/11.0 MB 1.1 MB/s eta 0:00:10
#    --- ------------------------------------ 1.0/11.0 MB 1.1 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.3/11.0 MB 1.1 MB/s eta 0:00:09
#    ----- ---------------------------------- 1.6/11.0 MB 1.2 MB/s eta 0:00:09
#    ------ --------------------------------- 1.8/11.0 MB 1.2 MB/s eta 0:00:08
#    ------- -------------------------------- 2.1/11.0 MB 1.2 MB/s eta 0:00:08
#    ------- -------------------------------- 2.1/11.0 MB 1.2 MB/s eta 0:00:08
#    -------- ------------------------------- 2.4/11.0 MB 1.2 MB/s eta 0:00:08
# ...

# %%
import pandas as pd

# %%
pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.1 MB 2.7 MB/s eta 0:00:03
#    ------ --------------------------------- 1.3/8.1 MB 2.7 MB/s eta 0:00:03
#    --------- ------------------------------ 1.8/8.1 MB 2.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.4/8.1 MB 2.7 MB/s eta 0:00:03
#    --------------- ------------------------ 3.1/8.1 MB 2.8 MB/s eta 0:00:02
#    ------------------ --------------------- 3.7/8.1 MB 2.9 MB/s eta 0:00:02
#    --------------------- ------------------ 4.5/8.1 MB 3.0 MB/s eta 0:00:02
#    ------------------------ --------------- 5.0/8.1 MB 3.0 MB/s eta 0:00:02
#    --------------------------- ------------ 5.5/8.1 MB 2.9 MB/s eta 0:00:01
#    ------------------------------- -------- 6.3/8.1 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.1/8.1 MB 3.0 MB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [raw]
# import seaborn as sns

# %%
 Load built-in datasets
tips = sns.load_dataset("tips")
mpg = sns.load_dataset("mpg")
flights = sns.load_dataset("flights")

 1. Scatter plot from tips dataset
plt.figure(figsize=(6,4))
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="sex", style="time")
plt.title("Scatter Plot - Tips Dataset")
plt.show()

 2. Box plot from mpg dataset
plt.figure(figsize=(6,4))
sns.boxplot(data=mpg, x="origin", y="mpg", palette="Set2")
plt.title("Box Plot - MPG Dataset")
plt.show()

 3. Line plot from flights dataset
plt.figure(figsize=(6,4))
sns.lineplot(data=flights, x="year", y="passengers", hue="month")
plt.title("Line Plot - Flights Dataset")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Load built-in datasets
# ----> 2 tips = sns.load_dataset("tips")
#       3 mpg = sns.load_dataset("mpg")
#       4 flights = sns.load_dataset("flights")
#
# NameError: name 'sns' is not defined

# %%
# Out:
#   Cell In[24], line 1
#     Load built-in datasets
#          ^
# SyntaxError: invalid syntax

# %%
import seaborn as sns

# %%
df= sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.xlabel('Category', color='blue', fontsize=12)
plt.ylabel('Profit', color='green', fontsize=12)
plt.title('Profit by Category', color='purple', fontsize=14)

plt.xticks(color='red', fontsize=10, rotation=45)
plt.yticks(color='brown', fontsize=10)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0, 0.0, '0.0'),
#   Text(0, 0.2, '0.2'),
#   Text(0, 0.4, '0.4'),
#   Text(0, 0.6000000000000001, '0.6'),
#   Text(0, 0.8, '0.8'),
#   Text(0, 1.0, '1.0')])

# %%
tips = sns.load_dataset("tips")
mpg = sns.load_dataset("mpg")
flights = sns.load_dataset("flights")

# %%
df= sns.load_dataset("mpg")

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df=sns.load_dataset("flights")

# %%
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="sex", style="time")
plt.title("Scatter Plot - Tips Dataset")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(data=mpg, x="origin", y="mpg", palette="Set2")
plt.title("Box Plot - MPG Dataset")
plt.show()
# Out:
# C:\Users\Ramyadevi\AppData\Local\Temp\ipykernel_18028\515265669.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=mpg, x="origin", y="mpg", palette="Set2")

# %%
plt.figure(figsize=(6,4))
sns.lineplot(data=flights, x="year", y="passengers", hue="month")
plt.title("Line Plot - Flights Dataset")
plt.show()
